# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !git clone https://github.com/wanpinglee/MOSAIK.git
# Out:
# Cloning into 'MOSAIK'...
# remote: Enumerating objects: 4691, done.
# remote: Total 4691 (delta 0), reused 0 (delta 0), pack-reused 4691
# Receiving objects: 100% (4691/4691), 12.20 MiB | 14.88 MiB/s, done.
# Resolving deltas: 100% (2913/2913), done.

# %%
# !cd /kaggle/working/MOSAIK/src && make
# Out:
# Building MOSAIK for the following platform: linux
# ...
# - Building in fann-2.1.0
#   * compiling floatfann.c
# In file included from floatfann.c:25:
# fann.c: In function ‘fann_print_connections’:
# fann.c:889:16: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘long int’ [-Wformat=]
#   889 |    printf("L %3d / N %4d %s\n", layer_it - ann->first_layer,
#       |              ~~^                ~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       |                |                         |
#       |                int                       long int
#       |              %3ld
# fann.c:889:24: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘long int’ [-Wformat=]
#   889 |    printf("L %3d / N %4d %s\n", layer_it - ann->first_layer,
#       |                      ~~^
#       |                        |
#       |                        int
#       |                      %4ld
#   890 |        neuron_it - ann->first_layer->first_neuron, neurons);
# ...

# %%
# !wget https://odin.mdacc.tmc.edu/~xsu1/hg19Virus.fa.gz
# Out:
# --2023-10-25 20:34:29--  https://odin.mdacc.tmc.edu/~xsu1/hg19Virus.fa.gz
# Resolving odin.mdacc.tmc.edu (odin.mdacc.tmc.edu)... 143.111.2.220
# Connecting to odin.mdacc.tmc.edu (odin.mdacc.tmc.edu)|143.111.2.220|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 944787247 (901M) [application/x-gzip]
# Saving to: ‘hg19Virus.fa.gz’
#
# hg19Virus.fa.gz     100%[===================>] 901.02M   794KB/s    in 19m 41s
#
# 2023-10-25 20:54:11 (781 KB/s) - ‘hg19Virus.fa.gz’ saved [944787247/944787247]

# %%
from IPython.display import FileLink 
# !tar -czvf my_work.zip -C . .
FileLink(r'my_work.zip')
# Out:
# ./
# ./MOSAIK/
# ./MOSAIK/.git/
# ./MOSAIK/.git/hooks/
# ./MOSAIK/.git/hooks/prepare-commit-msg.sample
# ./MOSAIK/.git/hooks/pre-receive.sample
# ./MOSAIK/.git/hooks/fsmonitor-watchman.sample
# ./MOSAIK/.git/hooks/pre-commit.sample
# ./MOSAIK/.git/hooks/pre-applypatch.sample
# ./MOSAIK/.git/hooks/post-update.sample
# ./MOSAIK/.git/hooks/pre-rebase.sample
# ./MOSAIK/.git/hooks/applypatch-msg.sample
# ./MOSAIK/.git/hooks/commit-msg.sample
# ./MOSAIK/.git/hooks/update.sample
# ./MOSAIK/.git/hooks/pre-merge-commit.sample
# ./MOSAIK/.git/hooks/pre-push.sample
# ./MOSAIK/.git/index
# ./MOSAIK/.git/info/
# ./MOSAIK/.git/info/exclude
# ./MOSAIK/.git/objects/
# ./MOSAIK/.git/objects/info/
# ./MOSAIK/.git/objects/pack/
# ./MOSAIK/.git/objects/pack/pack-0a575fe45fa048c2438a81384abb7872bebc40a5.idx
# ./MOSAIK/.git/objects/pack/pack-0a575fe45fa048c2438a81384abb7872bebc40a5.pack
# ./MOSAIK/.git/refs/
# ./MOSAIK/.git/refs/tags/
# ./MOSAIK/.git/refs/remotes/
# ./MOSAIK/.git/refs/remotes/origin/
# ...

# %%
rm my_work.zip

# %%
# !/kaggle/working/MOSAIK/bin/MosaikBuild -fr hg19Virus.fa -oa hg19Virus.fa.bin -assignQual 40
# Out:
# ------------------------------------------------------------------------------
# MosaikBuild 2.2.30                                                  2014-06-27
# Wan-Ping Lee & Michael Stromberg  Marth Lab, Boston College Biology Department
# ------------------------------------------------------------------------------
#
# ERROR: Could not open FASTA file (hg19Virus.fa) when performing integrity check.

# %%
# !/kaggle/working/MOSAIK/bin/MosaikJump -ia hg19.fa.bin -out hg19.JumpDb -hs 10
# Out:
# ------------------------------------------------------------------------------
# MosaikJump 2.2.30                                                   2014-06-27
# Wan-Ping Lee & Michael Stromberg  Marth Lab, Boston College Biology Department
# ------------------------------------------------------------------------------
#
# ERROR: Could not open hg19.fa.bin when validating the reference sequence archive.
