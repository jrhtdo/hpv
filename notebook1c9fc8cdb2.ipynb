# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/fffffffff/runAll.sh

# %%
# !git clone https://github.com/wanpinglee/MOSAIK.git
# Out:
# Cloning into 'MOSAIK'...
# remote: Enumerating objects: 4691, done.
# remote: Total 4691 (delta 0), reused 0 (delta 0), pack-reused 4691
# Receiving objects: 100% (4691/4691), 12.20 MiB | 22.10 MiB/s, done.
# Resolving deltas: 100% (2913/2913), done.

# %%
# !cd /kaggle/working/MOSAIK/src && make
# Out:
# Building MOSAIK for the following platform: linux
# ...
# - Building in fann-2.1.0
#   * compiling floatfann.c
# In file included from floatfann.c:25:
# fann.c: In function ‘fann_print_connections’:
# fann.c:889:16: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘long int’ [-Wformat=]
#   889 |    printf("L %3d / N %4d %s\n", layer_it - ann->first_layer,
#       |              ~~^                ~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       |                |                         |
#       |                int                       long int
#       |              %3ld
# fann.c:889:24: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘long int’ [-Wformat=]
#   889 |    printf("L %3d / N %4d %s\n", layer_it - ann->first_layer,
#       |                      ~~^
#       |                        |
#       |                        int
#       |                      %4ld
#   890 |        neuron_it - ann->first_layer->first_neuron, neurons);
# ...

# %%
# !wget http://downloads.hmpdacc.org/data/Illumina/anterior_nares/SRS011132.tar.bz2
# Out:
# --2023-10-26 01:18:05--  http://downloads.hmpdacc.org/data/Illumina/anterior_nares/SRS011132.tar.bz2
# Resolving downloads.hmpdacc.org (downloads.hmpdacc.org)... 134.192.156.26
# Connecting to downloads.hmpdacc.org (downloads.hmpdacc.org)|134.192.156.26|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30874163 (29M) [application/x-bzip2]
# Saving to: ‘SRS011132.tar.bz2’
#
# SRS011132.tar.bz2   100%[===================>]  29.44M  19.3MB/s    in 1.5s
#
# 2023-10-26 01:18:06 (19.3 MB/s) - ‘SRS011132.tar.bz2’ saved [30874163/30874163]

# %%
from IPython.display import FileLink 
# !tar -czvf my_work.zip -C . .
FileLink(r'my_work.zip')
# Out:
# ./
# ./__notebook__.ipynb
# ./SRS011132.tar.bz2
# ./MOSAIK/
# ./MOSAIK/README
# ./MOSAIK/obj/
# ./MOSAIK/obj/QualityNeuralNetwork.o
# ./MOSAIK/obj/BandedSmithWaterman.o
# ./MOSAIK/obj/AlignmentWriter.o
# ./MOSAIK/obj/fastlz.o
# ./MOSAIK/obj/ReadWriter.o
# ./MOSAIK/obj/MosaikBuild.o
# ./MOSAIK/obj/ArchiveSort.o
# ./MOSAIK/obj/BuildMain.o
# ./MOSAIK/obj/MultiDnaHash.o
# ./MOSAIK/obj/MosaikText.o
# ./MOSAIK/obj/SHA1.o
# ./MOSAIK/obj/ConvertSswToAlignment.o
# ./MOSAIK/obj/BestNSecondBestSelection.o
# ./MOSAIK/obj/UbiqDnaHash.o
# ./MOSAIK/obj/AbstractDnaHash.o
# ./MOSAIK/obj/NaiveAlignmentSet.o
# ./MOSAIK/obj/AlignmentThread.o
# ./MOSAIK/obj/TextMain.o
# ./MOSAIK/obj/Fasta.o
# ./MOSAIK/obj/CigarTager.o
# ./MOSAIK/obj/md5.o
# ./MOSAIK/obj/RegexUtilities.o
# ./MOSAIK/obj/MdTager.o
# ./MOSAIK/obj/ReferenceSequenceReader.o
# ./MOSAIK/obj/PairwiseUtilities.o
# ./MOSAIK/obj/MemoryUtilities.o
# ./MOSAIK/obj/TimeSupport.o
# ./MOSAIK/obj/SortThread.o
# ./MOSAIK/obj/JumpDnaHash.o
# ...

# %%
# !tar -xvjf /kaggle/working/SRS011132.tar.bz2 -C /kaggle/working/VirusSeqPipeline/samples
# Out:
# tar: /kaggle/working/VirusSeqPipeline/samples: Cannot open: No such file or directory
# tar: Error is not recoverable: exiting now

# %%
# !./MOSAIK/bin/MosaikBuild -fr gibVirus.fa -oa gibVirus.fa.bin -assignQual 40
# Out:
# ------------------------------------------------------------------------------
# MosaikBuild 2.2.30                                                  2014-06-27
# Wan-Ping Lee & Michael Stromberg  Marth Lab, Boston College Biology Department
# ------------------------------------------------------------------------------
#
# ERROR: Could not open FASTA file (gibVirus.fa) when performing integrity check.

# %%
# !/kaggle/working/MOSAIK/bin/MosaikJump -ia gibVirus.fa.bin -out gibVirus.JumpDb -hs 10
# Out:
# ------------------------------------------------------------------------------
# MosaikJump 2.2.30                                                   2014-06-27
# Wan-Ping Lee & Michael Stromberg  Marth Lab, Boston College Biology Department
# ------------------------------------------------------------------------------
#
# ERROR: Could not open gibVirus.fa.bin when validating the reference sequence archive.

# %%
# !git clone https://github.com/rosericazondekon/VirusSeqPipeline.git
# Out:
# Cloning into 'VirusSeqPipeline'...
# remote: Enumerating objects: 52, done.
# remote: Total 52 (delta 0), reused 0 (delta 0), pack-reused 52
# Unpacking objects: 100% (52/52), 7.01 MiB | 6.16 MiB/s, done.

# %%
# !cd /kaggle/working/VirusSeqPipeline/ && ./runAll.sh
# Out:
# /bin/bash: ./runAll.sh: Permission denied

# %%
# !ls -l /kaggle/working/VirusSeqPipeline/
# Out:
# total 36
# -rw-r--r-- 1 root root  959 Oct 26 01:18 AllowExec.txt
# drwxr-xr-x 2 root root 4096 Oct 26 01:18 Mosaik_JumpDb
# drwxr-xr-x 2 root root 4096 Oct 26 01:18 Mosaik_bin
# -rw-r--r-- 1 root root 6725 Oct 26 01:18 README.md
# drwxr-xr-x 2 root root 4096 Oct 26 01:18 VirusSeq_Script
# -rw-r--r-- 1 root root 8219 Oct 26 01:18 runAll.sh

# %%
# !/kaggle/working/VirusSeqPipeline/Mosaik_bin/MosaikBuild -q /kaggle/working/VirusSeqPipeline/samples/SRS011132/SRS011132.denovo_duplicates_marked.trimmed.1.fastq -q2 /kaggle/working/VirusSeqPipeline/samples/SRS011132/SRS011132.denovo_duplicates_marked.trimmed.2.fastq -out /kaggle/working/sample_Virus.bin -st illumina
# Out:
# /bin/bash: /kaggle/working/VirusSeqPipeline/Mosaik_bin/MosaikBuild: Permission denied

# %%
# !rm /kaggle/working/VirusSeqPipeline/runAll.sh
# !cp /kaggle/input/fffffffff/runAll.sh /kaggle/working/VirusSeqPipeline/

# %%
# !chmod 777 /kaggle/working/VirusSeqPipeline/runAll.sh
